# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
path = "College.csv"

college = pd.read_csv(path)
college
# Out:
#                          Unnamed: 0 Private   Apps  Accept  Enroll  Top10perc  \
# 0      Abilene Christian University     Yes   1660    1232     721         23
# 1                Adelphi University     Yes   2186    1924     512         16
# 2                    Adrian College     Yes   1428    1097     336         22
# 3               Agnes Scott College     Yes    417     349     137         60
# 4         Alaska Pacific University     Yes    193     146      55         16
# ..                              ...     ...    ...     ...     ...        ...
# 772         Worcester State College      No   2197    1515     543          4
# 773               Xavier University     Yes   1959    1805     695         24
# 774  Xavier University of Louisiana     Yes   2097    1915     695         34
# 775                 Yale University     Yes  10705    2453    1317         95
# 776    York College of Pennsylvania     Yes   2989    1855     691         28
#
# ...

# %%
college2 = pd.read_csv(path,index_col=0)
college2.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
#                               Room.Board  Books  Personal  PhD  Terminal  \
# ...

# %%
college3 = college.rename({"Unnamed: 0" : "College"}, axis=1)
college3.head()
# Out:
#                         College Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
# ...

# %%
college3 = college3.set_index("College")
college3.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# College
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
# ...

# %% [markdown]
# efter jämförelsena så kommer jag välja att fortgå med "collage3" för att där ser vi skolans namn mycket bättre

# %%
college = college3

college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %%
# colums = ['Top10perc', 'Apps', 'Enroll']
# pd.plotting.scatter_matrix(college[colums])

pd.plotting.scatter_matrix(college[['Top10perc', 'Apps', 'Enroll']])
pd
# Out:
# <module 'pandas' from 'c:\\Users\\frolu\\OneDrive\\Skrivbord\\skol kodning\\github2\\python-programming-ZEBASTIAN-ANDERSSON\\.venv\\Lib\\site-packages\\pandas\\__init__.py'>

# %%
sns.boxplot(data=college, y= 'Outstate', x ='Private')
plt.show()

# %%
#college["Elite"]

# %%
college["Elite"]=pd.cut(college["Top10perc"],[0,50,100],labels=["No","Yes"])
college["Elite"].value_counts()
# Out:
# Elite
# No     699
# Yes     78
# Name: count, dtype: int64

# %%
sns.boxplot(x =college["Elite"], y= college["Outstate"])
# Out:
# <Axes: xlabel='Elite', ylabel='Outstate'>

# %% [markdown]
# g) Use the plot.hist() method of college to produce some histograms with
# differing numbers of bins for a few of the quantitative variables. The command
# plt.subplots(2, 2) may be useful: it will divide the plot window into four re-
# gions so that four plots can be made simultaneously. By changing the arguments
# you can divide the screen up in other combinations.

# %%
college.columns
# Out:
# Index(['Private', 'Apps', 'Accept', 'Enroll', 'Top10perc', 'Top25perc',
#        'F.Undergrad', 'P.Undergrad', 'Outstate', 'Room.Board', 'Books',
#        'Personal', 'PhD', 'Terminal', 'S.F.Ratio', 'perc.alumni', 'Expend',
#        'Grad.Rate', 'Elite'],
#       dtype='object')

# %%
columns = ['Top10perc', 'Top25perc', 'Personal', 'Accept']

fig, axes = plt.subplots(2, 2, figsize=(10, 7))
axes = axes.flatten()

for ax, colum in zip(axes, columns):
    ax.hist(college[colum])
    ax.set_title(colum)

# %% [markdown]
# H)

# %% [markdown]
# (h) Continue exploring the data, and provide a brief summary of what you
# discover. Describe what you are looking for and what you find. For example,
# are there any correlations between personal spending, instructional spending
# and Elite status?

# %%
college.columns
# Out:
# Index(['Private', 'Apps', 'Accept', 'Enroll', 'Top10perc', 'Top25perc',
#        'F.Undergrad', 'P.Undergrad', 'Outstate', 'Room.Board', 'Books',
#        'Personal', 'PhD', 'Terminal', 'S.F.Ratio', 'perc.alumni', 'Expend',
#        'Grad.Rate', 'Elite'],
#       dtype='object')

# %% [markdown]
# det jag vill börja med att undersöka är om det är generellt dyrare med privatskolor både i skolkostnad och när det kommer till böcker. min tanke är att det kan bli dyrare med skolkostnad men att böckerna borde vara exakt detsamma priset eller nära nog att kunna säga att det inte är någon skillnad mellan dom

# %%
y = college[college["Private"] == "No"]["Books"].mean().round(2)
x = college[college["Private"] == "Yes"]["Books"].mean().round(2)

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

axes[0].hist(college[college["Private"] == "No"]["Books"])
axes[0].set_title(f"inte privat skola (mean={x})")
axes[0].set_xlabel("kostnad för böcker")
axes[0].set_ylabel("antalet skolor med priset")

axes[1].hist(college[college["Private"] == "Yes"]["Books"])
axes[1].set_title(f"privat skola (mean={y})")
axes[1].set_xlabel("kostnad för böcker")
axes[1].set_ylabel("antalet skolor med priset")
# Out:
# Text(0, 0.5, 'antalet skolor med priset')

# %% [markdown]
# det va ändå mer identiskt än va jag trodde det skulle vara men tack vare histogrammet ser vi dock att privatskolorna har den dyraste boken/böckerna och tycker det är intressant hur vi tydligt kan se att det verkligen är runt500-600kr i snitt medans på skolorna som inte är privata har ett större spann mer mellan 400-700kr för böckerna och kan även ha dom allra billigaste böckerna

# %% [markdown]
# space

# %% [markdown]
# Får privata eller offentliga skolor mest ansökningar? jag tänker att inte alla har pengarna/kontakterna att komma in på privata skolor så dom ansöker inte dit utan tror att vi tydligt kommer se att dom offentliga skolorna borde ha ungefär 1/3 mer ansökningar men vi tar en titt

# %%
college.groupby("Private")["Apps"].describe()
# Out:
#          count         mean          std    min      25%     50%     75%  \
# Private
# No       212.0  5729.919811  5370.675335  233.0  2190.75  4307.0  7722.5
# Yes      565.0  1977.929204  2443.341319   81.0   619.00  1133.0  2186.0
#
#              max
# Private
# No       48094.0
# Yes      20192.0

# %% [markdown]
# Det va lite som tänkt men det är mer än det dubbla faktiskt. Något annat jag ser är att skillnaden mellan max, min och medelvärdet är 2-3 gånger mer när det kommer till ansökningarna för dom offentliga skolorna i jämförelse till dom privata

# %% [markdown]
# det sista jag tänker att jag vill kolla in i är om antalet ansökningar påverkar hur många procent av dom som blir accepterade påverkas. tänker att desto mer som söker desto mindre % bör acceptera erbjudandet då detta antagligen är mer andrahandsval och desto mindre som ansöker desto mer accepterar då detta lär vara privatskolorna och kanske dom lite mer finare skolorna. men vi tar en koll

# %%
college
# Out:
#                                Private   Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University       Yes   1660    1232     721         23
# Adelphi University                 Yes   2186    1924     512         16
# Adrian College                     Yes   1428    1097     336         22
# Agnes Scott College                Yes    417     349     137         60
# Alaska Pacific University          Yes    193     146      55         16
# ...                                ...    ...     ...     ...        ...
# Worcester State College             No   2197    1515     543          4
# Xavier University                  Yes   1959    1805     695         24
# Xavier University of Louisiana     Yes   2097    1915     695         34
# Yale University                    Yes  10705    2453    1317         95
# York College of Pennsylvania       Yes   2989    1855     691         28
#
#                                 Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# ...

# %%
college.sort_values("%", ascending=False).head(5)
# Out:
#                                  Private  Apps  Accept  Enroll  Top10perc  \
# College
# California Lutheran University       Yes   563     247     247         23
# Brewton-Parker College               Yes  1436    1228    1202         10
# Mississippi University for Women      No   480     405     380         19
# Peru State College                    No   701     501     458         10
# Indiana Wesleyan University          Yes   735     423     366         20
#
#                                   Top25perc  F.Undergrad  P.Undergrad  \
# College
# California Lutheran University           52         1427          432
# Brewton-Parker College                   26         1320          822
# Mississippi University for Women         46         1673         1014
# Peru State College                       40          959          457
# Indiana Wesleyan University              48         2448          707
#
#                                   Outstate  Room.Board  Books  Personal  PhD  \
# ...

# %%
college["%"] = college["Enroll"]/college["Accept"]*100

ax = sns.scatterplot(data=college, x='%', y='Apps').set_xlabel("procent som tackade ja")

# %% [markdown]
# Resultatet är lite som förväntat i denhär skalan att desto mindre desto mer % valde att tacka ja till sin plats. men vill se hur det ser ut på en ska där vi drar ner maxantalet applikationer till 1000 och ser hur datan ser ut i den skalan

# %%
apps = college[college["Apps"] < 1000].sort_values("Apps")
ax = sns.scatterplot(data=apps, x='%', y='Apps').set_xlabel("procent som tackade ja")

# %% [markdown]
# Den blev helt klart lite mer intressant för jag kan inte längre direkt urskilja något mönster utan det är väldigt blandat. Så i just denna skalan kan man inte säga så mycket utan man måste ha med skolorna med allra mest ansökningar för att man egentligen ska kunna se en liten skillnad.
